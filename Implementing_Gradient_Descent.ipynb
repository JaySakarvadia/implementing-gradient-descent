# %% [markdown]
# <a href="https://colab.research.google.com/github/JaySakarvadia/implementing-gradient-descent/blob/main/Implementing_Gradient_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gradient Descent for a Linear Function
#
# Below is the equations for my chosen loss function, MSE (Mean Squared Error), as well as it's partial derivatives taken with respect to M (∂/∂m) and B (∂/∂b).
#
# ![1_LPu2GMI5Qx-YDuyBp-kRSg.webp](data:image/webp;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# Image credit to iManassa (https://medium.com/geekculture/mathematics-behind-gradient-descent-f2a49a0b714f)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#creation of data points
input = np.random.randn(10,1) #randomly formulated array of 10 x data points that fall on a normal distribution
output = 10 * input + np.random.rand() #randomly formulated array of 10 y data points that follow the y=mx+b form for interpretability

# %%
#visualizing our data to show linear relationship
sns.scatterplot(x=input[:, 0], y=output[:, 0])
plt.xlabel('X')
plt.ylabel('Y')
plt.title('relationship between x and y')
plt.show()

# %%
weights = 0.0
biases = 0.0
function = weights * input + biases #this is the function that will be updated (weights and biases) to fit our data
learning_rate = 0.01

# %%
def loss (output, function):
    sum_squared_error = 0

    for i in range(1, len(input)):
        sum_squared_error =+ ((output[i] - function[i])**2)

    MSE = sum_squared_error/len(input)

    return (MSE)

# %%
def gradient_descent (input, output, weights, biases, learning_rate):
    dweights = 0
    dbiases = 0
    n = input.shape[0]

    for xi, yi in zip(input, output):
        dweights += (-2/n) * xi[0] * (yi - (weights * xi[0] + biases)) #derived from MSE equation with respect to weights
        dbiases += (-2/n) * (yi - (weights * xi[0] + biases)) #derived from MSE equation with respect to biases

    weights = weights - learning_rate * dweights
    biases = biases - learning_rate * dbiases

    return (weights, biases)

# %%
for epoch in range (400):
    weights, biases = gradient_descent(input, output, weights, biases, learning_rate)
    function = weights * input + biases
    MSE = loss(output, function)
    print (f'Epoch: {epoch}     Loss: {MSE}     Weights: {weights}      Biases: {biases}')
# Out:
# Epoch: 0     Loss: [3.37738868]     Weights: [0.42971242]      Biases: [0.19972901]
# Epoch: 1     Loss: [3.1098585]     Weights: [0.84111043]      Biases: [0.39117796]
# Epoch: 2     Loss: [2.86382885]     Weights: [1.23497227]      Biases: [0.5746951]
# Epoch: 3     Loss: [2.63755451]     Weights: [1.61204315]      Biases: [0.75061396]
# Epoch: 4     Loss: [2.42943291]     Weights: [1.97303665]      Biases: [0.91925394]
# Epoch: 5     Loss: [2.23799241]     Weights: [2.31863606]      Biases: [1.08092097]
# Epoch: 6     Loss: [2.06188155]     Weights: [2.64949566]      Biases: [1.23590804]
# Epoch: 7     Loss: [1.89985917]     Weights: [2.96624195]      Biases: [1.38449573]
# Epoch: 8     Loss: [1.7507854]     Weights: [3.26947485]      Biases: [1.52695279]
# Epoch: 9     Loss: [1.6136133]     Weights: [3.55976881]      Biases: [1.66353659]
# Epoch: 10     Loss: [1.48738128]     Weights: [3.83767387]      Biases: [1.79449365]
# Epoch: 11     Loss: [1.3712061]     Weights: [4.10371674]      Biases: [1.92006005]
# Epoch: 12     Loss: [1.2642764]     Weights: [4.35840177]      Biases: [2.04046189]
# Epoch: 13     Loss: [1.1658469]     Weights: [4.60221188]      Biases: [2.15591576]
# Epoch: 14     Loss: [1.0752329]     Weights: [4.83560951]      Biases: [2.26662905]
# Epoch: 15     Loss: [0.99180538]     Weights: [5.05903745]      Biases: [2.37280042]
# Epoch: 16     Loss: [0.91498642]     Weights: [5.27291968]      Biases: [2.47462015]
# Epoch: 17     Loss: [0.84424503]     Weights: [5.47766221]      Biases: [2.57227045]
# Epoch: 18     Loss: [0.77909332]     Weights: [5.67365377]      Biases: [2.66592587]
# Epoch: 19     Loss: [0.71908295]     Weights: [5.86126662]      Biases: [2.75575357]
# Epoch: 20     Loss: [0.66380193]     Weights: [6.0408572]      Biases: [2.84191368]
# Epoch: 21     Loss: [0.61287163]     Weights: [6.21276679]      Biases: [2.92455955]
# Epoch: 22     Loss: [0.56594407]     Weights: [6.37732222]      Biases: [3.00383806]
# Epoch: 23     Loss: [0.52269942]     Weights: [6.53483641]      Biases: [3.0798899]
# Epoch: 24     Loss: [0.48284372]     Weights: [6.68560899]      Biases: [3.15284984]
# Epoch: 25     Loss: [0.44610671]     Weights: [6.82992689]      Biases: [3.22284694]
# Epoch: 26     Loss: [0.41223998]     Weights: [6.96806483]      Biases: [3.29000482]
# Epoch: 27     Loss: [0.38101515]     Weights: [7.10028587]      Biases: [3.35444192]
# Epoch: 28     Loss: [0.35222224]     Weights: [7.22684189]      Biases: [3.41627164]
# Epoch: 29     Loss: [0.32566817]     Weights: [7.34797409]      Biases: [3.47560264]
# Epoch: 30     Loss: [0.30117541]     Weights: [7.46391341]      Biases: [3.53253898]
# Epoch: 31     Loss: [0.2785807]     Weights: [7.57488097]      Biases: [3.58718034]
# Epoch: 32     Loss: [0.25773388]     Weights: [7.68108852]      Biases: [3.6396222]
# Epoch: 33     Loss: [0.23849686]     Weights: [7.78273881]      Biases: [3.68995603]
# Epoch: 34     Loss: [0.22074262]     Weights: [7.88002595]      Biases: [3.73826944]
# Epoch: 35     Loss: [0.2043543]     Weights: [7.97313584]      Biases: [3.78464634]
# Epoch: 36     Loss: [0.18922441]     Weights: [8.06224645]      Biases: [3.82916713]
# Epoch: 37     Loss: [0.17525405]     Weights: [8.14752822]      Biases: [3.87190881]
# Epoch: 38     Loss: [0.16235222]     Weights: [8.22914431]      Biases: [3.91294516]
# Epoch: 39     Loss: [0.15043517]     Weights: [8.30725099]      Biases: [3.95234682]
# Epoch: 40     Loss: [0.13942585]     Weights: [8.38199785]      Biases: [3.9901815]
# Epoch: 41     Loss: [0.12925333]     Weights: [8.45352814]      Biases: [4.02651405]
# Epoch: 42     Loss: [0.11985232]     Weights: [8.52197904]      Biases: [4.06140658]
# Epoch: 43     Loss: [0.11116273]     Weights: [8.58748185]      Biases: [4.0949186]
# Epoch: 44     Loss: [0.10312922]     Weights: [8.65016235]      Biases: [4.12710714]
# Epoch: 45     Loss: [0.09570087]     Weights: [8.71014092]      Biases: [4.15802679]
# Epoch: 46     Loss: [0.08883076]     Weights: [8.76753287]      Biases: [4.18772989]
# Epoch: 47     Loss: [0.08247569]     Weights: [8.82244856]      Biases: [4.21626657]
# Epoch: 48     Loss: [0.07659588]     Weights: [8.87499371]      Biases: [4.24368484]
# Epoch: 49     Loss: [0.07115469]     Weights: [8.92526949]      Biases: [4.27003072]
# Epoch: 50     Loss: [0.06611835]     Weights: [8.97337282]      Biases: [4.29534829]
# Epoch: 51     Loss: [0.06145576]     Weights: [9.01939646]      Biases: [4.31967977]
# Epoch: 52     Loss: [0.05713827]     Weights: [9.06342925]      Biases: [4.34306564]
# Epoch: 53     Loss: [0.05313946]     Weights: [9.10555623]      Biases: [4.36554465]
# Epoch: 54     Loss: [0.04943499]     Weights: [9.14585886]      Biases: [4.38715396]
# Epoch: 55     Loss: [0.04600243]     Weights: [9.18441508]      Biases: [4.40792914]
# Epoch: 56     Loss: [0.0428211]     Weights: [9.22129957]      Biases: [4.42790431]
# Epoch: 57     Loss: [0.03987191]     Weights: [9.2565838]      Biases: [4.44711213]
# Epoch: 58     Loss: [0.0371373]     Weights: [9.2903362]      Biases: [4.4655839]
# Epoch: 59     Loss: [0.03460105]     Weights: [9.32262231]      Biases: [4.48334963]
# Epoch: 60     Loss: [0.03224819]     Weights: [9.35350487]      Biases: [4.50043806]
# Epoch: 61     Loss: [0.03006492]     Weights: [9.38304393]      Biases: [4.51687673]
# Epoch: 62     Loss: [0.02803853]     Weights: [9.41129702]      Biases: [4.53269203]
# Epoch: 63     Loss: [0.02615725]     Weights: [9.4383192]      Biases: [4.54790927]
# Epoch: 64     Loss: [0.02441026]     Weights: [9.46416318]      Biases: [4.56255267]
# Epoch: 65     Loss: [0.02278753]     Weights: [9.48887945]      Biases: [4.57664547]
# Epoch: 66     Loss: [0.02127984]     Weights: [9.51251633]      Biases: [4.59020991]
# Epoch: 67     Loss: [0.01987866]     Weights: [9.53512009]      Biases: [4.60326734]
# Epoch: 68     Loss: [0.01857611]     Weights: [9.55673503]      Biases: [4.61583819]
# Epoch: 69     Loss: [0.01736491]     Weights: [9.57740357]      Biases: [4.62794207]
# Epoch: 70     Loss: [0.01623835]     Weights: [9.5971663]      Biases: [4.63959774]
# Epoch: 71     Loss: [0.01519021]     Weights: [9.61606211]      Biases: [4.6508232]
# Epoch: 72     Loss: [0.01421476]     Weights: [9.63412822]      Biases: [4.66163572]
# Epoch: 73     Loss: [0.0133067]     Weights: [9.65140026]      Biases: [4.6720518]
# Epoch: 74     Loss: [0.01246113]     Weights: [9.66791234]      Biases: [4.68208732]
# Epoch: 75     Loss: [0.01167351]     Weights: [9.68369713]      Biases: [4.69175745]
# Epoch: 76     Loss: [0.01093966]     Weights: [9.6987859]      Biases: [4.70107676]
# Epoch: 77     Loss: [0.01025569]     Weights: [9.71320859]      Biases: [4.7100592]
# Epoch: 78     Loss: [0.00961803]     Weights: [9.72699385]      Biases: [4.71871816]
# Epoch: 79     Loss: [0.00902335]     Weights: [9.74016913]      Biases: [4.72706646]
# Epoch: 80     Loss: [0.0084686]     Weights: [9.75276069]      Biases: [4.7351164]
# Epoch: 81     Loss: [0.00795092]     Weights: [9.76479368]      Biases: [4.74287976]
# Epoch: 82     Loss: [0.00746768]     Weights: [9.77629218]      Biases: [4.75036786]
# Epoch: 83     Loss: [0.00701646]     Weights: [9.78727923]      Biases: [4.75759152]
# Epoch: 84     Loss: [0.00659499]     Weights: [9.7977769]      Biases: [4.76456113]
# Epoch: 85     Loss: [0.00620119]     Weights: [9.80780631]      Biases: [4.77128666]
# Epoch: 86     Loss: [0.00583311]     Weights: [9.81738769]      Biases: [4.77777765]
# Epoch: 87     Loss: [0.00548897]     Weights: [9.82654038]      Biases: [4.78404327]
# Epoch: 88     Loss: [0.00516711]     Weights: [9.83528292]      Biases: [4.7900923]
# Epoch: 89     Loss: [0.00486598]     Weights: [9.84363305]      Biases: [4.79593317]
# Epoch: 90     Loss: [0.00458415]     Weights: [9.85160776]      Biases: [4.80157393]
# Epoch: 91     Loss: [0.00432029]     Weights: [9.85922329]      Biases: [4.80702236]
# Epoch: 92     Loss: [0.00407318]     Weights: [9.86649521]      Biases: [4.81228586]
# Epoch: 93     Loss: [0.00384167]     Weights: [9.87343842]      Biases: [4.81737157]
# Epoch: 94     Loss: [0.0036247]     Weights: [9.88006717]      Biases: [4.82228633]
# Epoch: 95     Loss: [0.0034213]     Weights: [9.88639511]      Biases: [4.82703668]
# Epoch: 96     Loss: [0.00323054]     Weights: [9.89243532]      Biases: [4.83162892]
# Epoch: 97     Loss: [0.00305158]     Weights: [9.89820029]      Biases: [4.83606907]
# Epoch: 98     Loss: [0.00288363]     Weights: [9.90370199]      Biases: [4.84036293]
# Epoch: 99     Loss: [0.00272596]     Weights: [9.9089519]      Biases: [4.84451604]
# Epoch: 100     Loss: [0.00257788]     Weights: [9.91396097]      Biases: [4.84853373]
# Epoch: 101     Loss: [0.00243876]     Weights: [9.9187397]      Biases: [4.85242112]
# Epoch: 102     Loss: [0.00230802]     Weights: [9.92329815]      Biases: [4.8561831]
# Epoch: 103     Loss: [0.00218511]     Weights: [9.92764592]      Biases: [4.85982437]
# Epoch: 104     Loss: [0.00206951]     Weights: [9.93179223]      Biases: [4.86334947]
# Epoch: 105     Loss: [0.00196075]     Weights: [9.93574589]      Biases: [4.86676271]
# Epoch: 106     Loss: [0.00185839]     Weights: [9.93951533]      Biases: [4.87006825]
# Epoch: 107     Loss: [0.00176203]     Weights: [9.94310863]      Biases: [4.87327009]
# Epoch: 108     Loss: [0.00167127]     Weights: [9.9465335]      Biases: [4.87637206]
# Epoch: 109     Loss: [0.00158576]     Weights: [9.94979734]      Biases: [4.87937784]
# Epoch: 110     Loss: [0.00150517]     Weights: [9.95290723]      Biases: [4.88229095]
# Epoch: 111     Loss: [0.00142918]     Weights: [9.95586994]      Biases: [4.88511478]
# Epoch: 112     Loss: [0.00135751]     Weights: [9.95869195]      Biases: [4.88785259]
# Epoch: 113     Loss: [0.00128989]     Weights: [9.96137947]      Biases: [4.8905075]
# Epoch: 114     Loss: [0.00122607]     Weights: [9.96393842]      Biases: [4.89308251]
# Epoch: 115     Loss: [0.00116581]     Weights: [9.96637449]      Biases: [4.8955805]
# Epoch: 116     Loss: [0.00110889]     Weights: [9.96869311]      Biases: [4.89800423]
# Epoch: 117     Loss: [0.00105511]     Weights: [9.97089949]      Biases: [4.90035637]
# Epoch: 118     Loss: [0.00100428]     Weights: [9.9729986]      Biases: [4.90263946]
# Epoch: 119     Loss: [0.00095621]     Weights: [9.97499521]      Biases: [4.90485595]
# Epoch: 120     Loss: [0.00091075]     Weights: [9.97689388]      Biases: [4.9070082]
# Epoch: 121     Loss: [0.00086774]     Weights: [9.97869895]      Biases: [4.90909847]
# Epoch: 122     Loss: [0.00082702]     Weights: [9.98041462]      Biases: [4.91112894]
# Epoch: 123     Loss: [0.00078847]     Weights: [9.98204487]      Biases: [4.91310168]
# Epoch: 124     Loss: [0.00075195]     Weights: [9.98359352]      Biases: [4.91501871]
# Epoch: 125     Loss: [0.00071735]     Weights: [9.98506423]      Biases: [4.91688196]
# Epoch: 126     Loss: [0.00068455]     Weights: [9.98646049]      Biases: [4.91869327]
# Epoch: 127     Loss: [0.00065345]     Weights: [9.98778565]      Biases: [4.92045443]
# Epoch: 128     Loss: [0.00062395]     Weights: [9.98904291]      Biases: [4.92216716]
# Epoch: 129     Loss: [0.00059596]     Weights: [9.99023533]      Biases: [4.92383309]
# Epoch: 130     Loss: [0.0005694]     Weights: [9.99136584]      Biases: [4.92545381]
# Epoch: 131     Loss: [0.00054418]     Weights: [9.99243725]      Biases: [4.92703084]
# Epoch: 132     Loss: [0.00052022]     Weights: [9.99345224]      Biases: [4.92856565]
# Epoch: 133     Loss: [0.00049746]     Weights: [9.99441336]      Biases: [4.93005963]
# Epoch: 134     Loss: [0.00047582]     Weights: [9.99532307]      Biases: [4.93151416]
# Epoch: 135     Loss: [0.00045526]     Weights: [9.99618373]      Biases: [4.93293051]
# Epoch: 136     Loss: [0.0004357]     Weights: [9.99699757]      Biases: [4.93430996]
# Epoch: 137     Loss: [0.00041709]     Weights: [9.99776673]      Biases: [4.93565371]
# Epoch: 138     Loss: [0.00039938]     Weights: [9.99849328]      Biases: [4.93696291]
# Epoch: 139     Loss: [0.00038252]     Weights: [9.99917918]      Biases: [4.93823867]
# Epoch: 140     Loss: [0.00036646]     Weights: [9.9998263]      Biases: [4.93948209]
# Epoch: 141     Loss: [0.00035117]     Weights: [10.00043643]      Biases: [4.94069418]
# Epoch: 142     Loss: [0.0003366]     Weights: [10.00101131]      Biases: [4.94187594]
# Epoch: 143     Loss: [0.00032271]     Weights: [10.00155256]      Biases: [4.94302834]
# Epoch: 144     Loss: [0.00030947]     Weights: [10.00206176]      Biases: [4.94415229]
# Epoch: 145     Loss: [0.00029684]     Weights: [10.00254041]      Biases: [4.94524868]
# Epoch: 146     Loss: [0.00028479]     Weights: [10.00298994]      Biases: [4.94631837]
# Epoch: 147     Loss: [0.00027329]     Weights: [10.00341173]      Biases: [4.94736218]
# Epoch: 148     Loss: [0.00026232]     Weights: [10.00380709]      Biases: [4.94838092]
# Epoch: 149     Loss: [0.00025184]     Weights: [10.00417727]      Biases: [4.94937533]
# Epoch: 150     Loss: [0.00024183]     Weights: [10.00452347]      Biases: [4.95034616]
# Epoch: 151     Loss: [0.00023226]     Weights: [10.00484684]      Biases: [4.95129413]
# Epoch: 152     Loss: [0.00022312]     Weights: [10.00514847]      Biases: [4.95221991]
# Epoch: 153     Loss: [0.00021439]     Weights: [10.00542941]      Biases: [4.95312417]
# Epoch: 154     Loss: [0.00020604]     Weights: [10.00569067]      Biases: [4.95400753]
# Epoch: 155     Loss: [0.00019805]     Weights: [10.00593319]      Biases: [4.95487063]
# Epoch: 156     Loss: [0.0001904]     Weights: [10.00615789]      Biases: [4.95571405]
# Epoch: 157     Loss: [0.00018309]     Weights: [10.00636564]      Biases: [4.95653836]
# Epoch: 158     Loss: [0.00017609]     Weights: [10.00655728]      Biases: [4.9573441]
# Epoch: 159     Loss: [0.00016939]     Weights: [10.00673361]      Biases: [4.95813183]
# Epoch: 160     Loss: [0.00016297]     Weights: [10.00689538]      Biases: [4.95890204]
# Epoch: 161     Loss: [0.00015682]     Weights: [10.00704333]      Biases: [4.95965523]
# Epoch: 162     Loss: [0.00015093]     Weights: [10.00717814]      Biases: [4.96039188]
# Epoch: 163     Loss: [0.00014528]     Weights: [10.00730049]      Biases: [4.96111246]
# Epoch: 164     Loss: [0.00013987]     Weights: [10.007411]      Biases: [4.9618174]
# Epoch: 165     Loss: [0.00013468]     Weights: [10.00751029]      Biases: [4.96250714]
# Epoch: 166     Loss: [0.00012971]     Weights: [10.00759892]      Biases: [4.9631821]
# Epoch: 167     Loss: [0.00012493]     Weights: [10.00767746]      Biases: [4.96384268]
# Epoch: 168     Loss: [0.00012035]     Weights: [10.00774643]      Biases: [4.96448926]
# Epoch: 169     Loss: [0.00011596]     Weights: [10.00780633]      Biases: [4.96512222]
# Epoch: 170     Loss: [0.00011174]     Weights: [10.00785764]      Biases: [4.96574192]
# Epoch: 171     Loss: [0.00010769]     Weights: [10.00790082]      Biases: [4.96634872]
# Epoch: 172     Loss: [0.0001038]     Weights: [10.00793631]      Biases: [4.96694295]
# Epoch: 173     Loss: [0.00010007]     Weights: [10.00796453]      Biases: [4.96752494]
# Epoch: 174     Loss: [9.64794779e-05]     Weights: [10.00798587]      Biases: [4.96809502]
# Epoch: 175     Loss: [9.30318312e-05]     Weights: [10.00800071]      Biases: [4.96865347]
# Epoch: 176     Loss: [8.97185754e-05]     Weights: [10.00800942]      Biases: [4.96920061]
# Epoch: 177     Loss: [8.65338691e-05]     Weights: [10.00801234]      Biases: [4.96973672]
# Epoch: 178     Loss: [8.34721562e-05]     Weights: [10.00800981]      Biases: [4.97026208]
# Epoch: 179     Loss: [8.05281497e-05]     Weights: [10.00800213]      Biases: [4.97077696]
# Epoch: 180     Loss: [7.76968177e-05]     Weights: [10.00798961]      Biases: [4.97128162]
# Epoch: 181     Loss: [7.49733695e-05]     Weights: [10.00797253]      Biases: [4.9717763]
# Epoch: 182     Loss: [7.23532428e-05]     Weights: [10.00795117]      Biases: [4.97226127]
# Epoch: 183     Loss: [6.98320916e-05]     Weights: [10.00792578]      Biases: [4.97273675]
# Epoch: 184     Loss: [6.74057749e-05]     Weights: [10.00789662]      Biases: [4.97320297]
# Epoch: 185     Loss: [6.50703456e-05]     Weights: [10.00786391]      Biases: [4.97366016]
# Epoch: 186     Loss: [6.28220411e-05]     Weights: [10.00782788]      Biases: [4.97410853]
# Epoch: 187     Loss: [6.06572726e-05]     Weights: [10.00778876]      Biases: [4.97454829]
# Epoch: 188     Loss: [5.85726174e-05]     Weights: [10.00774673]      Biases: [4.97497965]
# Epoch: 189     Loss: [5.65648092e-05]     Weights: [10.007702]      Biases: [4.9754028]
# Epoch: 190     Loss: [5.4630731e-05]     Weights: [10.00765474]      Biases: [4.97581793]
# Epoch: 191     Loss: [5.27674069e-05]     Weights: [10.00760515]      Biases: [4.97622523]
# Epoch: 192     Loss: [5.09719953e-05]     Weights: [10.00755337]      Biases: [4.97662488]
# Epoch: 193     Loss: [4.92417821e-05]     Weights: [10.00749957]      Biases: [4.97701706]
# Epoch: 194     Loss: [4.75741741e-05]     Weights: [10.00744391]      Biases: [4.97740192]
# Epoch: 195     Loss: [4.59666933e-05]     Weights: [10.00738652]      Biases: [4.97777965]
# Epoch: 196     Loss: [4.44169708e-05]     Weights: [10.00732755]      Biases: [4.97815039]
# Epoch: 197     Loss: [4.29227419e-05]     Weights: [10.00726712]      Biases: [4.9785143]
# Epoch: 198     Loss: [4.14818406e-05]     Weights: [10.00720535]      Biases: [4.97887154]
# Epoch: 199     Loss: [4.0092195e-05]     Weights: [10.00714237]      Biases: [4.97922225]
# Epoch: 200     Loss: [3.87518225e-05]     Weights: [10.00707828]      Biases: [4.97956658]
# Epoch: 201     Loss: [3.74588258e-05]     Weights: [10.0070132]      Biases: [4.97990466]
# Epoch: 202     Loss: [3.62113887e-05]     Weights: [10.00694721]      Biases: [4.98023662]
# Epoch: 203     Loss: [3.50077722e-05]     Weights: [10.00688042]      Biases: [4.98056261]
# Epoch: 204     Loss: [3.38463106e-05]     Weights: [10.00681292]      Biases: [4.98088274]
# Epoch: 205     Loss: [3.27254085e-05]     Weights: [10.00674478]      Biases: [4.98119714]
# Epoch: 206     Loss: [3.16435372e-05]     Weights: [10.0066761]      Biases: [4.98150593]
# Epoch: 207     Loss: [3.05992316e-05]     Weights: [10.00660695]      Biases: [4.98180923]
# Epoch: 208     Loss: [2.95910873e-05]     Weights: [10.0065374]      Biases: [4.98210715]
# Epoch: 209     Loss: [2.86177578e-05]     Weights: [10.00646753]      Biases: [4.98239981]
# Epoch: 210     Loss: [2.76779519e-05]     Weights: [10.00639738]      Biases: [4.98268732]
# Epoch: 211     Loss: [2.6770431e-05]     Weights: [10.00632704]      Biases: [4.98296977]
# Epoch: 212     Loss: [2.58940067e-05]     Weights: [10.00625655]      Biases: [4.98324728]
# Epoch: 213     Loss: [2.50475388e-05]     Weights: [10.00618597]      Biases: [4.98351994]
# Epoch: 214     Loss: [2.4229933e-05]     Weights: [10.00611535]      Biases: [4.98378785]
# Epoch: 215     Loss: [2.34401385e-05]     Weights: [10.00604474]      Biases: [4.9840511]
# Epoch: 216     Loss: [2.26771467e-05]     Weights: [10.00597419]      Biases: [4.98430979]
# Epoch: 217     Loss: [2.19399888e-05]     Weights: [10.00590374]      Biases: [4.98456402]
# Epoch: 218     Loss: [2.12277342e-05]     Weights: [10.00583343]      Biases: [4.98481386]
# Epoch: 219     Loss: [2.05394891e-05]     Weights: [10.00576329]      Biases: [4.98505941]
# Epoch: 220     Loss: [1.98743944e-05]     Weights: [10.00569338]      Biases: [4.98530074]
# Epoch: 221     Loss: [1.92316245e-05]     Weights: [10.00562371]      Biases: [4.98553795]
# Epoch: 222     Loss: [1.86103859e-05]     Weights: [10.00555432]      Biases: [4.9857711]
# Epoch: 223     Loss: [1.80099157e-05]     Weights: [10.00548525]      Biases: [4.98600029]
# Epoch: 224     Loss: [1.74294803e-05]     Weights: [10.00541651]      Biases: [4.98622558]
# Epoch: 225     Loss: [1.6868374e-05]     Weights: [10.00534814]      Biases: [4.98644705]
# Epoch: 226     Loss: [1.63259183e-05]     Weights: [10.00528015]      Biases: [4.98666477]
# Epoch: 227     Loss: [1.58014602e-05]     Weights: [10.00521258]      Biases: [4.98687882]
# Epoch: 228     Loss: [1.52943716e-05]     Weights: [10.00514543]      Biases: [4.98708926]
# Epoch: 229     Loss: [1.48040477e-05]     Weights: [10.00507874]      Biases: [4.98729616]
# Epoch: 230     Loss: [1.43299067e-05]     Weights: [10.00501252]      Biases: [4.98749959]
# Epoch: 231     Loss: [1.38713883e-05]     Weights: [10.00494679]      Biases: [4.9876996]
# Epoch: 232     Loss: [1.34279532e-05]     Weights: [10.00488156]      Biases: [4.98789628]
# Epoch: 233     Loss: [1.2999082e-05]     Weights: [10.00481684]      Biases: [4.98808967]
# Epoch: 234     Loss: [1.25842744e-05]     Weights: [10.00475265]      Biases: [4.98827984]
# Epoch: 235     Loss: [1.21830487e-05]     Weights: [10.00468901]      Biases: [4.98846684]
# Epoch: 236     Loss: [1.17949406e-05]     Weights: [10.00462592]      Biases: [4.98865074]
# Epoch: 237     Loss: [1.14195029e-05]     Weights: [10.00456339]      Biases: [4.9888316]
# Epoch: 238     Loss: [1.10563047e-05]     Weights: [10.00450143]      Biases: [4.98900945]
# Epoch: 239     Loss: [1.07049305e-05]     Weights: [10.00444005]      Biases: [4.98918437]
# Epoch: 240     Loss: [1.03649801e-05]     Weights: [10.00437926]      Biases: [4.9893564]
# Epoch: 241     Loss: [1.00360675e-05]     Weights: [10.00431906]      Biases: [4.9895256]
# Epoch: 242     Loss: [9.71782067e-06]     Weights: [10.00425946]      Biases: [4.98969202]
# Epoch: 243     Loss: [9.40988076e-06]     Weights: [10.00420047]      Biases: [4.9898557]
# Epoch: 244     Loss: [9.11190181e-06]     Weights: [10.00414208]      Biases: [4.99001669]
# Epoch: 245     Loss: [8.82355013e-06]     Weights: [10.00408431]      Biases: [4.99017505]
# Epoch: 246     Loss: [8.54450382e-06]     Weights: [10.00402715]      Biases: [4.99033082]
# Epoch: 247     Loss: [8.2744524e-06]     Weights: [10.00397061]      Biases: [4.99048404]
# Epoch: 248     Loss: [8.01309626e-06]     Weights: [10.00391469]      Biases: [4.99063476]
# Epoch: 249     Loss: [7.76014636e-06]     Weights: [10.00385939]      Biases: [4.99078302]
# Epoch: 250     Loss: [7.51532375e-06]     Weights: [10.00380471]      Biases: [4.99092887]
# Epoch: 251     Loss: [7.27835923e-06]     Weights: [10.00375066]      Biases: [4.99107235]
# Epoch: 252     Loss: [7.04899294e-06]     Weights: [10.00369722]      Biases: [4.9912135]
# Epoch: 253     Loss: [6.82697409e-06]     Weights: [10.00364441]      Biases: [4.99135236]
# Epoch: 254     Loss: [6.61206051e-06]     Weights: [10.00359222]      Biases: [4.99148896]
# Epoch: 255     Loss: [6.40401845e-06]     Weights: [10.00354065]      Biases: [4.99162336]
# Epoch: 256     Loss: [6.20262217e-06]     Weights: [10.0034897]      Biases: [4.99175558]
# Epoch: 257     Loss: [6.0076537e-06]     Weights: [10.00343936]      Biases: [4.99188567]
# Epoch: 258     Loss: [5.81890253e-06]     Weights: [10.00338964]      Biases: [4.99201365]
# Epoch: 259     Loss: [5.63616536e-06]     Weights: [10.00334054]      Biases: [4.99213958]
# Epoch: 260     Loss: [5.4592458e-06]     Weights: [10.00329204]      Biases: [4.99226347]
# Epoch: 261     Loss: [5.28795416e-06]     Weights: [10.00324415]      Biases: [4.99238537]
# Epoch: 262     Loss: [5.12210718e-06]     Weights: [10.00319686]      Biases: [4.99250531]
# Epoch: 263     Loss: [4.9615278e-06]     Weights: [10.00315017]      Biases: [4.99262332]
# Epoch: 264     Loss: [4.80604496e-06]     Weights: [10.00310408]      Biases: [4.99273944]
# Epoch: 265     Loss: [4.65549335e-06]     Weights: [10.00305858]      Biases: [4.99285369]
# Epoch: 266     Loss: [4.50971323e-06]     Weights: [10.00301367]      Biases: [4.99296612]
# Epoch: 267     Loss: [4.36855021e-06]     Weights: [10.00296934]      Biases: [4.99307674]
# Epoch: 268     Loss: [4.23185511e-06]     Weights: [10.0029256]      Biases: [4.99318559]
# Epoch: 269     Loss: [4.0994837e-06]     Weights: [10.00288243]      Biases: [4.9932927]
# Epoch: 270     Loss: [3.97129657e-06]     Weights: [10.00283983]      Biases: [4.9933981]
# Epoch: 271     Loss: [3.84715897e-06]     Weights: [10.0027978]      Biases: [4.99350182]
# Epoch: 272     Loss: [3.72694063e-06]     Weights: [10.00275633]      Biases: [4.99360388]
# Epoch: 273     Loss: [3.61051558e-06]     Weights: [10.00271542]      Biases: [4.99370431]
# Epoch: 274     Loss: [3.49776206e-06]     Weights: [10.00267506]      Biases: [4.99380315]
# Epoch: 275     Loss: [3.38856229e-06]     Weights: [10.00263525]      Biases: [4.99390041]
# Epoch: 276     Loss: [3.28280244e-06]     Weights: [10.00259598]      Biases: [4.99399612]
# Epoch: 277     Loss: [3.18037237e-06]     Weights: [10.00255725]      Biases: [4.9940903]
# Epoch: 278     Loss: [3.08116561e-06]     Weights: [10.00251905]      Biases: [4.994183]
# Epoch: 279     Loss: [2.98507916e-06]     Weights: [10.00248138]      Biases: [4.99427421]
# Epoch: 280     Loss: [2.89201342e-06]     Weights: [10.00244423]      Biases: [4.99436398]
# Epoch: 281     Loss: [2.80187204e-06]     Weights: [10.00240759]      Biases: [4.99445233]
# Epoch: 282     Loss: [2.71456182e-06]     Weights: [10.00237147]      Biases: [4.99453927]
# Epoch: 283     Loss: [2.62999263e-06]     Weights: [10.00233585]      Biases: [4.99462483]
# Epoch: 284     Loss: [2.54807723e-06]     Weights: [10.00230073]      Biases: [4.99470904]
# Epoch: 285     Loss: [2.46873127e-06]     Weights: [10.0022661]      Biases: [4.99479192]
# Epoch: 286     Loss: [2.39187312e-06]     Weights: [10.00223196]      Biases: [4.99487348]
# Epoch: 287     Loss: [2.3174238e-06]     Weights: [10.00219831]      Biases: [4.99495375]
# Epoch: 288     Loss: [2.24530691e-06]     Weights: [10.00216513]      Biases: [4.99503275]
# Epoch: 289     Loss: [2.1754485e-06]     Weights: [10.00213243]      Biases: [4.9951105]
# Epoch: 290     Loss: [2.10777704e-06]     Weights: [10.00210019]      Biases: [4.99518703]
# Epoch: 291     Loss: [2.04222329e-06]     Weights: [10.00206841]      Biases: [4.99526234]
# Epoch: 292     Loss: [1.97872026e-06]     Weights: [10.00203709]      Biases: [4.99533647]
# Epoch: 293     Loss: [1.91720312e-06]     Weights: [10.00200622]      Biases: [4.99540942]
# Epoch: 294     Loss: [1.85760911e-06]     Weights: [10.0019758]      Biases: [4.99548123]
# Epoch: 295     Loss: [1.79987751e-06]     Weights: [10.00194581]      Biases: [4.9955519]
# Epoch: 296     Loss: [1.74394955e-06]     Weights: [10.00191626]      Biases: [4.99562145]
# Epoch: 297     Loss: [1.68976834e-06]     Weights: [10.00188714]      Biases: [4.99568991]
# Epoch: 298     Loss: [1.63727881e-06]     Weights: [10.00185844]      Biases: [4.99575729]
# Epoch: 299     Loss: [1.58642767e-06]     Weights: [10.00183016]      Biases: [4.99582361]
# Epoch: 300     Loss: [1.53716333e-06]     Weights: [10.00180229]      Biases: [4.99588889]
# Epoch: 301     Loss: [1.48943584e-06]     Weights: [10.00177483]      Biases: [4.99595314]
# Epoch: 302     Loss: [1.44319686e-06]     Weights: [10.00174778]      Biases: [4.99601638]
# Epoch: 303     Loss: [1.39839959e-06]     Weights: [10.00172112]      Biases: [4.99607862]
# Epoch: 304     Loss: [1.35499872e-06]     Weights: [10.00169485]      Biases: [4.99613988]
# Epoch: 305     Loss: [1.31295038e-06]     Weights: [10.00166897]      Biases: [4.99620018]
# Epoch: 306     Loss: [1.27221212e-06]     Weights: [10.00164347]      Biases: [4.99625953]
# Epoch: 307     Loss: [1.23274281e-06]     Weights: [10.00161834]      Biases: [4.99631795]
# Epoch: 308     Loss: [1.19450264e-06]     Weights: [10.00159359]      Biases: [4.99637545]
# Epoch: 309     Loss: [1.15745307e-06]     Weights: [10.00156921]      Biases: [4.99643205]
# Epoch: 310     Loss: [1.12155679e-06]     Weights: [10.00154518]      Biases: [4.99648776]
# Epoch: 311     Loss: [1.08677765e-06]     Weights: [10.00152152]      Biases: [4.9965426]
# Epoch: 312     Loss: [1.05308067e-06]     Weights: [10.0014982]      Biases: [4.99659657]
# Epoch: 313     Loss: [1.02043197e-06]     Weights: [10.00147524]      Biases: [4.9966497]
# Epoch: 314     Loss: [9.88798733e-07]     Weights: [10.00145261]      Biases: [4.99670199]
# Epoch: 315     Loss: [9.58149193e-07]     Weights: [10.00143032]      Biases: [4.99675346]
# Epoch: 316     Loss: [9.28452584e-07]     Weights: [10.00140837]      Biases: [4.99680413]
# Epoch: 317     Loss: [8.99679113e-07]     Weights: [10.00138675]      Biases: [4.996854]
# Epoch: 318     Loss: [8.71799927e-07]     Weights: [10.00136545]      Biases: [4.99690309]
# Epoch: 319     Loss: [8.44787084e-07]     Weights: [10.00134447]      Biases: [4.99695141]
# Epoch: 320     Loss: [8.18613524e-07]     Weights: [10.0013238]      Biases: [4.99699898]
# Epoch: 321     Loss: [7.9325304e-07]     Weights: [10.00130344]      Biases: [4.99704579]
# Epoch: 322     Loss: [7.68680251e-07]     Weights: [10.00128339]      Biases: [4.99709188]
# Epoch: 323     Loss: [7.44870574e-07]     Weights: [10.00126365]      Biases: [4.99713724]
# Epoch: 324     Loss: [7.21800201e-07]     Weights: [10.0012442]      Biases: [4.9971819]
# Epoch: 325     Loss: [6.99446074e-07]     Weights: [10.00122504]      Biases: [4.99722585]
# Epoch: 326     Loss: [6.77785857e-07]     Weights: [10.00120618]      Biases: [4.99726912]
# Epoch: 327     Loss: [6.56797919e-07]     Weights: [10.00118759]      Biases: [4.9973117]
# Epoch: 328     Loss: [6.36461308e-07]     Weights: [10.00116929]      Biases: [4.99735363]
# Epoch: 329     Loss: [6.16755729e-07]     Weights: [10.00115127]      Biases: [4.99739489]
# Epoch: 330     Loss: [5.97661524e-07]     Weights: [10.00113352]      Biases: [4.99743551]
# Epoch: 331     Loss: [5.79159653e-07]     Weights: [10.00111604]      Biases: [4.9974755]
# Epoch: 332     Loss: [5.61231673e-07]     Weights: [10.00109882]      Biases: [4.99751486]
# Epoch: 333     Loss: [5.43859717e-07]     Weights: [10.00108187]      Biases: [4.9975536]
# Epoch: 334     Loss: [5.27026481e-07]     Weights: [10.00106517]      Biases: [4.99759174]
# Epoch: 335     Loss: [5.107152e-07]     Weights: [10.00104873]      Biases: [4.99762928]
# Epoch: 336     Loss: [4.94909637e-07]     Weights: [10.00103254]      Biases: [4.99766624]
# Epoch: 337     Loss: [4.79594061e-07]     Weights: [10.00101659]      Biases: [4.99770262]
# Epoch: 338     Loss: [4.64753234e-07]     Weights: [10.00100089]      Biases: [4.99773843]
# Epoch: 339     Loss: [4.50372395e-07]     Weights: [10.00098542]      Biases: [4.99777368]
# Epoch: 340     Loss: [4.36437244e-07]     Weights: [10.00097019]      Biases: [4.99780837]
# Epoch: 341     Loss: [4.22933927e-07]     Weights: [10.0009552]      Biases: [4.99784253]
# Epoch: 342     Loss: [4.09849025e-07]     Weights: [10.00094043]      Biases: [4.99787615]
# Epoch: 343     Loss: [3.97169538e-07]     Weights: [10.00092589]      Biases: [4.99790925]
# Epoch: 344     Loss: [3.8488287e-07]     Weights: [10.00091157]      Biases: [4.99794183]
# Epoch: 345     Loss: [3.7297682e-07]     Weights: [10.00089747]      Biases: [4.99797391]
# Epoch: 346     Loss: [3.61439566e-07]     Weights: [10.00088359]      Biases: [4.99800548]
# Epoch: 347     Loss: [3.50259658e-07]     Weights: [10.00086992]      Biases: [4.99803656]
# Epoch: 348     Loss: [3.39426001e-07]     Weights: [10.00085645]      Biases: [4.99806715]
# Epoch: 349     Loss: [3.28927845e-07]     Weights: [10.0008432]      Biases: [4.99809727]
# Epoch: 350     Loss: [3.18754777e-07]     Weights: [10.00083014]      Biases: [4.99812691]
# Epoch: 351     Loss: [3.08896708e-07]     Weights: [10.00081729]      Biases: [4.99815609]
# Epoch: 352     Loss: [2.99343863e-07]     Weights: [10.00080464]      Biases: [4.99818482]
# Epoch: 353     Loss: [2.90086773e-07]     Weights: [10.00079217]      Biases: [4.9982131]
# Epoch: 354     Loss: [2.81116261e-07]     Weights: [10.0007799]      Biases: [4.99824094]
# Epoch: 355     Loss: [2.7242344e-07]     Weights: [10.00076782]      Biases: [4.99826834]
# Epoch: 356     Loss: [2.63999695e-07]     Weights: [10.00075593]      Biases: [4.99829532]
# Epoch: 357     Loss: [2.55836683e-07]     Weights: [10.00074421]      Biases: [4.99832187]
# Epoch: 358     Loss: [2.47926318e-07]     Weights: [10.00073268]      Biases: [4.99834801]
# Epoch: 359     Loss: [2.40260767e-07]     Weights: [10.00072133]      Biases: [4.99837375]
# Epoch: 360     Loss: [2.3283244e-07]     Weights: [10.00071014]      Biases: [4.99839908]
# Epoch: 361     Loss: [2.25633984e-07]     Weights: [10.00069914]      Biases: [4.99842401]
# Epoch: 362     Loss: [2.18658273e-07]     Weights: [10.0006883]      Biases: [4.99844856]
# Epoch: 363     Loss: [2.11898404e-07]     Weights: [10.00067762]      Biases: [4.99847272]
# Epoch: 364     Loss: [2.05347688e-07]     Weights: [10.00066712]      Biases: [4.99849651]
# Epoch: 365     Loss: [1.98999645e-07]     Weights: [10.00065677]      Biases: [4.99851993]
# Epoch: 366     Loss: [1.92847993e-07]     Weights: [10.00064658]      Biases: [4.99854298]
# Epoch: 367     Loss: [1.8688665e-07]     Weights: [10.00063655]      Biases: [4.99856567]
# Epoch: 368     Loss: [1.81109719e-07]     Weights: [10.00062668]      Biases: [4.99858801]
# Epoch: 369     Loss: [1.75511488e-07]     Weights: [10.00061696]      Biases: [4.99861]
# Epoch: 370     Loss: [1.70086421e-07]     Weights: [10.00060738]      Biases: [4.99863165]
# Epoch: 371     Loss: [1.64829157e-07]     Weights: [10.00059796]      Biases: [4.99865296]
# Epoch: 372     Loss: [1.59734497e-07]     Weights: [10.00058868]      Biases: [4.99867394]
# Epoch: 373     Loss: [1.54797407e-07]     Weights: [10.00057954]      Biases: [4.99869459]
# Epoch: 374     Loss: [1.50013007e-07]     Weights: [10.00057055]      Biases: [4.99871491]
# Epoch: 375     Loss: [1.4537657e-07]     Weights: [10.00056169]      Biases: [4.99873493]
# Epoch: 376     Loss: [1.40883514e-07]     Weights: [10.00055297]      Biases: [4.99875463]
# Epoch: 377     Loss: [1.36529402e-07]     Weights: [10.00054439]      Biases: [4.99877402]
# Epoch: 378     Loss: [1.32309931e-07]     Weights: [10.00053594]      Biases: [4.99879311]
# Epoch: 379     Loss: [1.28220934e-07]     Weights: [10.00052761]      Biases: [4.9988119]
# Epoch: 380     Loss: [1.24258372e-07]     Weights: [10.00051942]      Biases: [4.9988304]
# Epoch: 381     Loss: [1.20418333e-07]     Weights: [10.00051136]      Biases: [4.99884861]
# Epoch: 382     Loss: [1.16697024e-07]     Weights: [10.00050342]      Biases: [4.99886654]
# Epoch: 383     Loss: [1.1309077e-07]     Weights: [10.0004956]      Biases: [4.99888419]
# Epoch: 384     Loss: [1.09596012e-07]     Weights: [10.0004879]      Biases: [4.99890156]
# Epoch: 385     Loss: [1.06209299e-07]     Weights: [10.00048032]      Biases: [4.99891867]
# Epoch: 386     Loss: [1.02927287e-07]     Weights: [10.00047286]      Biases: [4.9989355]
# Epoch: 387     Loss: [9.97467386e-08]     Weights: [10.00046552]      Biases: [4.99895208]
# Epoch: 388     Loss: [9.6664513e-08]     Weights: [10.00045828]      Biases: [4.99896839]
# Epoch: 389     Loss: [9.36775687e-08]     Weights: [10.00045116]      Biases: [4.99898446]
# Epoch: 390     Loss: [9.0782958e-08]     Weights: [10.00044415]      Biases: [4.99900027]
# Epoch: 391     Loss: [8.79778245e-08]     Weights: [10.00043725]      Biases: [4.99901583]
# Epoch: 392     Loss: [8.52594004e-08]     Weights: [10.00043046]      Biases: [4.99903115]
# Epoch: 393     Loss: [8.26250036e-08]     Weights: [10.00042377]      Biases: [4.99904624]
# Epoch: 394     Loss: [8.00720349e-08]     Weights: [10.00041719]      Biases: [4.99906109]
# Epoch: 395     Loss: [7.75979758e-08]     Weights: [10.0004107]      Biases: [4.99907571]
# Epoch: 396     Loss: [7.52003857e-08]     Weights: [10.00040432]      Biases: [4.9990901]
# Epoch: 397     Loss: [7.28768996e-08]     Weights: [10.00039804]      Biases: [4.99910426]
# Epoch: 398     Loss: [7.06252258e-08]     Weights: [10.00039185]      Biases: [4.99911821]
# Epoch: 399     Loss: [6.84431434e-08]     Weights: [10.00038576]      Biases: [4.99913193]
